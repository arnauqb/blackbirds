# %% [markdown]
# # SIR model

# %% [markdown]
# Here we calibrate a differentiable version of the SIR model.
# We use the exact same model as  https://ndlib.readthedocs.io/en/latest/reference/models/epidemics/SIR.html,
# but implemented in a differentiable way.

# %%
from birds.models.sir import SIR
from birds.calibrator import Calibrator

import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx
import normflows as nf
from corner import corner # to plot corner plots

# %% [markdown]
# ## Generating synthetic true data

# %%
# generate a random graph
n_agents = 1000
graph = networkx.watts_strogatz_graph(n_agents, 10, 0.1)

# %%
sir = SIR(graph, n_timesteps=100)

# %%
# %%time
# the simulator takes as parameters the log10 of the fraction of initial cases, beta, and gamma parameters
true_parameters = torch.log10(torch.tensor([0.05, 0.05, 0.05]))
true_data = sir(true_parameters)
true_infected, true_recovered = true_data
# Out:
# CPU times: user 39.1 ms, sys: 15.8 ms, total: 54.8 ms
# Wall time: 43 ms

# %%
f, ax = plt.subplots()
ax.plot(true_infected, label = "active infected")
ax.set_xlabel("Time-step")
ax.plot(true_recovered, label = "cumulative recovered")
ax.legend()

# %% [markdown]
# ## Approximating the posterior by a normalizing flow

# %% [markdown]
# ### Constructing the flow using normflows (https://github.com/VincentStimper/normalizing-flows )

# %% [markdown]
# In this case we define Neural Spline Flow with 4 transformations, each parametrised by 2 layers with 64 hidden units.

# %%
# Define flows
K = 4
torch.manual_seed(0)

latent_size = 3
hidden_units = 64
hidden_layers = 2

flows = []
for i in range(K):
    flows += [nf.flows.AutoregressiveRationalQuadraticSpline(latent_size, hidden_layers, hidden_units)]
    flows += [nf.flows.LULinearPermute(latent_size)]

# Set prior and q0
q0 = nf.distributions.DiagGaussian(3, trainable=False)
    
# Construct flow model
flow = nf.NormalizingFlow(q0=q0, flows=flows)

# %%
# Plot the inital flow:
samples = flow.sample(10000)[0].detach().numpy()

corner(samples, truths=true_parameters.numpy());

# %% [markdown]
# Let's also plot runs sampled from the untrained flow, to compare later with the trained flow.

# %%
# compare the predictions to the synthetic data:

f, ax = plt.subplots()

for i in range(15):
    with torch.no_grad():
        sim_sir = sir(flow.sample(1)[0][0])
    ax.plot(sim_sir[0].numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[1].numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_data[0], color = "black", linewidth=2, label = "data infected")
ax.plot(true_data[1], color = "black", linewidth=2, label = "data recovered", linestyle="--")

ax.legend()

# %% [markdown]
# ### Train the flow

# %%
torch.manual_seed(0)

# Define a prior
prior = torch.distributions.MultivariateNormal(-2.0 * torch.ones(3), torch.eye(3))

optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-3)

# We set the regularisation weight to 10.
w = 100

# Note that we can track the progress of the training by using tensorboard.
# tensorboard --logdir=runs
log_dir = "./runs/sir_run"

calibrator = Calibrator(model = sir, posterior_estimator = flow, prior=prior, data=true_data, optimizer=optimizer, w=w, tensorboard_log_dir=log_dir)

# and we run for 500 epochs without early stopping.

calibrator.run(n_epochs=500, max_epochs_without_improvement=np.inf);
# Out:
#   0%|▊                                                                                                                                                                                                | 2/500 [00:02<09:40,  1.17s/it, Forecast=2.52e+5, Reg.=559, total=2.53e+5, best loss=2.53e+5, epochs since improv.=0]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 19
#      15 calibrator = Calibrator(model = sir, posterior_estimator = flow, prior=prior, data=true_data, optimizer=optimizer, w=w, tensorboard_log_dir=log_dir)
#      17 # and we run for 500 epochs without early stopping.
# ---> 19 calibrator.run(n_epochs=500, max_epochs_without_improvement=np.inf);
#
# File ~/code/birds/birds/calibrator.py:152, in Calibrator.run(self, n_epochs, max_epochs_without_improvement)
#     150 self.losses_hist = defaultdict(list)
#     151 for epoch in iterator:
# --> 152     loss, forecast_loss, regularisation_loss = self.step()
#     153     if mpi_rank == 0:
#     154         self.losses_hist["total"].append(loss.item())
#
# File ~/code/birds/birds/calibrator.py:107, in Calibrator.step(self)
#     101 if mpi_rank == 0:
#     102     self.optimizer.zero_grad()
#     103 (
#     104     forecast_parameters,
#     105     forecast_loss,
#     106     forecast_jacobians,
# --> 107 ) = compute_forecast_loss_and_jacobian(
#     108     loss_fn=self.forecast_loss,
#     109     model=self.model,
#     110     parameter_generator=lambda x: self.posterior_estimator.sample(x)[0],
#     111     observed_outputs=self.data,
#     112     n_samples=self.n_samples_per_epoch,
#     113     diff_mode=self.diff_mode,
#     114     device=self.device,
#     115 )
#     116 if mpi_rank == 0:
#     117     regularisation_loss = self.w * compute_regularisation_loss(
#     118         posterior_estimator=self.posterior_estimator,
#     119         prior=self.prior,
#     120         n_samples=self.n_samples_regularisation,
#     121     )
#
# File ~/code/birds/birds/forecast.py:74, in compute_forecast_loss_and_jacobian(loss_fn, model, parameter_generator, n_samples, observed_outputs, diff_mode, jacobian_chunk_size, device)
#      72 # Rank 0 samples from the flow
#      73 if mpi_rank == 0:
# ---> 74     params_list = parameter_generator(n_samples)
#      75     params_list_comm = params_list.detach().cpu().numpy()
#      76 else:
#
# File ~/code/birds/birds/calibrator.py:110, in Calibrator.step.<locals>.<lambda>(x)
#     101 if mpi_rank == 0:
#     102     self.optimizer.zero_grad()
#     103 (
#     104     forecast_parameters,
#     105     forecast_loss,
#     106     forecast_jacobians,
#     107 ) = compute_forecast_loss_and_jacobian(
#     108     loss_fn=self.forecast_loss,
#     109     model=self.model,
# --> 110     parameter_generator=lambda x: self.posterior_estimator.sample(x)[0],
#     111     observed_outputs=self.data,
#     112     n_samples=self.n_samples_per_epoch,
#     113     diff_mode=self.diff_mode,
#     114     device=self.device,
#     115 )
#     116 if mpi_rank == 0:
#     117     regularisation_loss = self.w * compute_regularisation_loss(
#     118         posterior_estimator=self.posterior_estimator,
#     119         prior=self.prior,
#     120         n_samples=self.n_samples_regularisation,
#     121     )
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/normflows/core.py:178, in NormalizingFlow.sample(self, num_samples)
#     176 z, log_q = self.q0(num_samples)
#     177 for flow in self.flows:
# --> 178     z, log_det = flow(z)
#     179     log_q -= log_det
#     180 return z, log_q
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/normflows/flows/neural_spline/wrapper.py:225, in AutoregressiveRationalQuadraticSpline.forward(self, z)
#     224 def forward(self, z):
# --> 225     z, log_det = self.mprqat.inverse(z)
#     226     return z, log_det.view(-1)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/normflows/flows/affine/autoregressive.py:35, in Autoregressive.inverse(self, inputs, context)
#      33 for _ in range(num_inputs):
#      34     autoregressive_params = self.autoregressive_net(outputs, context)
# ---> 35     outputs, logabsdet = self._elementwise_inverse(
#      36         inputs, autoregressive_params
#      37     )
#      38 return outputs, logabsdet
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/normflows/flows/neural_spline/autoregressive.py:134, in MaskedPiecewiseRationalQuadraticAutoregressive._elementwise_inverse(self, inputs, autoregressive_params)
#     133 def _elementwise_inverse(self, inputs, autoregressive_params):
# --> 134     return self._elementwise(inputs, autoregressive_params, inverse=True)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/normflows/flows/neural_spline/autoregressive.py:116, in MaskedPiecewiseRationalQuadraticAutoregressive._elementwise(self, inputs, autoregressive_params, inverse)
#     113     spline_fn = splines.unconstrained_rational_quadratic_spline
#     114     spline_kwargs = {"tails": self.tails, "tail_bound": self.tail_bound}
# --> 116 outputs, logabsdet = spline_fn(
#     117     inputs=inputs,
#     118     unnormalized_widths=unnormalized_widths,
#     119     unnormalized_heights=unnormalized_heights,
#     120     unnormalized_derivatives=unnormalized_derivatives,
#     121     inverse=inverse,
#     122     min_bin_width=self.min_bin_width,
#     123     min_bin_height=self.min_bin_height,
#     124     min_derivative=self.min_derivative,
#     125     **spline_kwargs
#     126 )
#     128 return outputs, utils.sum_except_batch(logabsdet)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/normflows/utils/splines.py:76, in unconstrained_rational_quadratic_spline(inputs, unnormalized_widths, unnormalized_heights, unnormalized_derivatives, inverse, tails, tail_bound, min_bin_width, min_bin_height, min_derivative)
#      70     bottom = -tail_bound
#      71     top = tail_bound
#      73 (
#      74     outputs[inside_interval_mask],
#      75     logabsdet[inside_interval_mask],
# ---> 76 ) = rational_quadratic_spline(
#      77     inputs=inputs[inside_interval_mask],
#      78     unnormalized_widths=unnormalized_widths[inside_interval_mask, :],
#      79     unnormalized_heights=unnormalized_heights[inside_interval_mask, :],
#      80     unnormalized_derivatives=unnormalized_derivatives_[inside_interval_mask, :],
#      81     inverse=inverse,
#      82     left=left,
#      83     right=right,
#      84     bottom=bottom,
#      85     top=top,
#      86     min_bin_width=min_bin_width,
#      87     min_bin_height=min_bin_height,
#      88     min_derivative=min_derivative,
#      89 )
#      91 return outputs, logabsdet
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/normflows/utils/splines.py:175, in rational_quadratic_spline(inputs, unnormalized_widths, unnormalized_heights, unnormalized_derivatives, inverse, left, right, bottom, top, min_bin_width, min_bin_height, min_derivative)
#     172 c = -input_delta * (inputs - input_cumheights)
#     174 discriminant = b.pow(2) - 4 * a * c
# --> 175 assert (discriminant >= 0).all()
#     177 root = (2 * c) / (-b - torch.sqrt(discriminant))
#     178 outputs = root * input_bin_widths + input_cumwidths
#
# AssertionError:

# %%
# Let's have a look at the loss over epochs:

df = pd.DataFrame(calibrator.losses_hist)
df.plot(logy=True)

# %%
# We can load the best model to check the results
flow.load_state_dict(calibrator.best_model_state_dict)

# %%
# Plot the final flow posterior approximator and compare it to the real parameters:
samples = flow.sample(10000)[0].detach().numpy()

corner(samples, truths=true_parameters.numpy(), smooth=2, range = ((-1.6, -0.8), (-1.5, -1), (-1.4, -1.15)));

# %%
# compare the predictions to the synthetic data:

f, ax = plt.subplots()

for i in range(25):
    with torch.no_grad():
        sim_sir = sir(flow.sample(1)[0][0])
    ax.plot(sim_sir[0].numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[1].numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_data[0], color = "black", linewidth=2, label = "data infected")
ax.plot(true_data[1], color = "black", linewidth=2, label = "data recovered", linestyle="--")

ax.legend()
