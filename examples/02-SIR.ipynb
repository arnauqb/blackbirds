# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # SIR model

# %% [markdown]
# Here we calibrate a differentiable version of the SIR model.
# We use the exact same model as  https://ndlib.readthedocs.io/en/latest/reference/models/epidemics/SIR.html,
# but implemented in a differentiable way.

# %%
from birds.models.sir import SIR
from birds.calibrator import Calibrator

import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx
import normflows as nf
import pygtc

# %% [markdown]
# ## Generating synthetic true data

# %%
device = "cpu"

# %%
# generate a random graph
n_agents = 1000
graph = networkx.watts_strogatz_graph(n_agents, 10, 0.1)

# %%
sir = SIR(graph, n_timesteps=100, device=device)

# %%
# %%time
# the simulator takes as parameters the log10 of the fraction of initial cases, beta, and gamma parameters
true_parameters = torch.log10(torch.tensor([0.05, 0.05, 0.05], device=device))
true_data = sir.run_and_observe(true_parameters)
true_infected, true_recovered = true_data
# Out:
# CPU times: user 4.8 s, sys: 0 ns, total: 4.8 s
# Wall time: 151 ms

# %%
f, ax = plt.subplots()
ax.plot(true_infected.cpu(), label = "active infected")
ax.set_xlabel("Time-step")
ax.plot(true_recovered.cpu(), label = "cumulative recovered")
ax.legend()

# %% [markdown]
# ## Approximating the posterior by a normalizing flow

# %% [markdown]
# We construct the flow using the normflows library (https://github.com/VincentStimper/normalizing-flows )

# %% [markdown]
# In this case we define Neural Spline Flow with 4 transformations, each parametrised by 2 layers with 64 hidden units.

# %%
def make_flow(n_parameters):
    torch.manual_seed(0)
    base = nf.distributions.base.DiagGaussian(n_parameters)
    num_layers = 5
    flows = []
    for i in range(num_layers):
        param_map = nf.nets.MLP([n_parameters // 2 + 1, 50, 50, 2], init_zeros=True)
        flows.append(nf.flows.AffineCouplingBlock(param_map))
        flows.append(nf.flows.Permute(n_parameters, mode='swap'))
    return nf.NormalizingFlow(base, flows).to(device)

# %%
# Plot the inital flow:
flow = make_flow(len(true_parameters))
samples = flow.sample(10000)[0].cpu().detach().numpy()

pygtc.plotGTC([samples], truths=true_parameters.cpu().numpy(), figureSize=7, paramNames=[r"$I_0$", r"$\beta$", r"$\gamma$"]);

# %% [markdown]
# Let's also plot runs sampled from the untrained flow, to compare later with the trained flow.

# %%
f, ax = plt.subplots()

for i in range(15):
    with torch.no_grad():
        sim_sir = sir.run_and_observe(flow.sample(1)[0][0])
    ax.plot(sim_sir[0].cpu().numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[1].cpu().numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_data[0].cpu(), color = "black", linewidth=2, label = "data infected")
ax.plot(true_data[1].cpu(), color = "black", linewidth=2, label = "data recovered", linestyle="--")
ax.legend()

# %% [markdown]
# ### Train the flow

# %%
torch.manual_seed(0)

# Define a prior
prior = torch.distributions.MultivariateNormal(-2.0 * torch.ones(3, device=device), torch.eye(3, device=device))

optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-3)

# We set the regularisation weight to 10.
w = 10

calibrator = Calibrator(model = sir,
                        posterior_estimator = flow,
                        prior=prior,
                        data=true_data,
                        optimizer=optimizer,
                        w=w,
                        n_samples_per_epoch=5,
                        log_tensorboard=True,
                        device=device
                       )

# and we run for 1000 epochs, stopping if the loss doesn't improve in 100 epochs.
calibrator.run(n_epochs=1000, max_epochs_without_improvement=100);
# Out:
#   0%|                                | 3/1000 [00:10<57:01,  3.43s/it, Forecast=2.28e+5, Reg.=58.2, total=2.28e+5, best loss=2.25e+5, epochs since improv.=2]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 23
#      11 calibrator = Calibrator(model = sir,
#      12                         posterior_estimator = flow,
#      13                         prior=prior,
#    (...)
#      19                         device=device
#      20                        )
#      22 # and we run for 1000 epochs, stopping if the loss doesn't improve in 100 epochs.
# ---> 23 calibrator.run(n_epochs=1000, max_epochs_without_improvement=100)
#
# File ~/birds/birds/calibrator.py:146, in Calibrator.run(self, n_epochs, max_epochs_without_improvement)
#     144 self.losses_hist = defaultdict(list)
#     145 for epoch in iterator:
# --> 146     loss, forecast_loss, regularisation_loss = self.step()
#     147     if mpi_rank == 0:
#     148         self.losses_hist["total"].append(loss.item())
#
# File ~/birds/birds/calibrator.py:98, in Calibrator.step(self)
#      96     self.optimizer.zero_grad()
#      97 # compute and differentiate forecast loss
# ---> 98 forecast_loss = compute_and_differentiate_forecast_loss(
#      99     loss_fn=self.forecast_loss,
#     100     model=self.model,
#     101     posterior_estimator=self.posterior_estimator,
#     102     n_samples=self.n_samples_per_epoch,
#     103     observed_outputs=self.data,
#     104     diff_mode=self.diff_mode,
#     105     gradient_estimation_method=self.gradient_estimation_method,
#     106     jacobian_chunk_size=self.jacobian_chunk_size,
#     107     gradient_horizon=self.gradient_horizon,
#     108     device=self.device,
#     109 )
#     110 # compute and differentiate regularisation loss
#     111 if mpi_rank == 0:
#
# File ~/birds/birds/forecast.py:352, in compute_and_differentiate_forecast_loss(loss_fn, model, posterior_estimator, n_samples, observed_outputs, diff_mode, gradient_estimation_method, jacobian_chunk_size, gradient_horizon, device)
#     332 r"""Computes and differentiates the forecast loss according to the chosen gradient estimation method
#     333 and automatic differentiation mechanism.
#     334 **Arguments:**
#    (...)
#     345 - `device`: device to use for the computation
#     346 """
#     347 if gradient_estimation_method == "pathwise":
#     348     (
#     349         forecast_parameters,
#     350         forecast_loss,
#     351         forecast_jacobians,
# --> 352     ) = compute_forecast_loss_and_jacobian_pathwise(
#     353         loss_fn=loss_fn,
#     354         model=model,
#     355         posterior_estimator=posterior_estimator,
#     356         observed_outputs=observed_outputs,
#     357         n_samples=n_samples,
#     358         diff_mode=diff_mode,
#     359         device=device,
#     360         jacobian_chunk_size=jacobian_chunk_size,
#     361         gradient_horizon=gradient_horizon,
#     362     )
#     363     if mpi_rank == 0:
#     364         _differentiate_forecast_loss_pathwise(
#     365             forecast_parameters, forecast_jacobians
#     366         )
#
# File ~/birds/birds/forecast.py:210, in compute_forecast_loss_and_jacobian_pathwise(loss_fn, model, posterior_estimator, n_samples, observed_outputs, diff_mode, jacobian_chunk_size, gradient_horizon, device)
#     208 for i in range(mpi_rank, len(params_list_comm), mpi_size):
#     209     params = torch.tensor(params_list_comm[i], device=device)
# --> 210     jacobian, loss_i = jacobian_calculator(params)
#     211     if torch.isnan(loss_i) or torch.isnan(jacobian).any():
#     212         continue
#
# File ~/.conda/envs/torch/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:489, in jacrev.<locals>.wrapper_fn(*args)
#     486 @wraps(func)
#     487 def wrapper_fn(*args):
#     488     error_if_complex("jacrev", args, is_input=True)
# --> 489     vjp_out = _vjp_with_argnums(func, *args, argnums=argnums, has_aux=has_aux)
#     490     if has_aux:
#     491         output, vjp_fn, aux = vjp_out
#
# File ~/.conda/envs/torch/lib/python3.10/site-packages/torch/_functorch/vmap.py:39, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      36 @functools.wraps(f)
#      37 def fn(*args, **kwargs):
#      38     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 39         return f(*args, **kwargs)
#
# File ~/.conda/envs/torch/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:291, in _vjp_with_argnums(func, argnums, has_aux, *primals)
#     289     diff_primals = _slice_argnums(primals, argnums, as_tuple=False)
#     290     tree_map_(partial(_create_differentiable, level=level), diff_primals)
# --> 291 primals_out = func(*primals)
#     293 if has_aux:
#     294     if not (isinstance(primals_out, tuple) and len(primals_out) == 2):
#
# File ~/birds/birds/forecast.py:194, in compute_forecast_loss_and_jacobian_pathwise.<locals>.loss_f(params)
#     193 def loss_f(params):
# --> 194     simulated_outputs = simulate_and_observe_model(model, params, gradient_horizon)
#     195     loss = compute_loss(loss_fn, observed_outputs, simulated_outputs)
#     196     return loss
#
# File ~/birds/birds/forecast.py:45, in simulate_and_observe_model(model, params, gradient_horizon)
#      41     # stack with the last gradient_horizon time-steps
#      42     time_series = torch.cat(
#      43         (no_gradient_time_series, time_series[len(time_series) - gradient_horizon:])
#      44     )
# ---> 45 x = model(params, time_series)
#      46 observed_outputs = [
#      47     torch.cat((observed_output, output))
#      48     for observed_output, output in zip(observed_outputs, model.observe(x))
#      49 ]
#      50 time_series = torch.cat((time_series, x))
#
# File ~/birds/birds/models/model.py:16, in Model.__call__(self, params, x)
#      15 def __call__(self, params, x):
# ---> 16     return self.step(params, x)
#
# File ~/birds/birds/models/sir.py:74, in SIR.step(self, params, x)
#      65 def step(self, params: torch.Tensor, x: torch.Tensor):
#      66     """
#      67     Runs the model forward for one timestep.
#      68
#    (...)
#      72     - x: a tensor of shape (3, n_agents) containing the infected, susceptible, and recovered counts.
#      73     """
# ---> 74     params = soft_minimum(params, torch.tensor(0.0, device=params.device), 2)
#      75     params = 10**params
#      76     _, beta, gamma = params
#
# File ~/birds/birds/utils.py:25, in soft_minimum(a, b, k)
#      16 def soft_minimum(a, b, k):
#      17     """
#      18     Soft differentiable minimum function.
#      19
#    (...)
#      23         k (float): Hardness.
#      24     """
# ---> 25     return -soft_maximum(-a, -b, k)
#
# File ~/birds/birds/utils.py:13, in soft_maximum(a, b, k)
#       4 def soft_maximum(a, b, k):
#       5     """
#       6     Soft differentiable maximum function.
#       7
#    (...)
#      11         k (float): Hardness.
#      12     """
# ---> 13     return torch.log(torch.exp(k * a) + torch.exp(k * b)) / k
#
# KeyboardInterrupt:

# %%
# Let's have a look at the loss over epochs:

df = pd.DataFrame(calibrator.losses_hist)
df.plot(logy=True)

# %%
# We can load the best model to check the results
flow.load_state_dict(calibrator.best_model_state_dict)

# %%
# Plot the final flow posterior approximator and compare it to the real parameters:
samples = flow.sample(50000)[0].detach().numpy()

#corner(samples, truths=true_parameters.numpy(), smooth=2, range = ((-2, -1.0), (-1.7, -1.0), (-1.4, -1.25)), labels=["initial_fraction_infected", r"$\beta$", r"$\gamma$"]);
#corner(samples, truths=true_parameters.numpy(), smooth=2, labels=["initial_fraction_infected", r"$\beta$", r"$\gamma$"]);
pygtc.plotGTC([samples], truths=true_parameters.numpy(), figureSize=10, priors=[(-2, 1) for i in range(3)]);

# %%
# compare the predictions to the synthetic data:

f, ax = plt.subplots()

for i in range(25):
    with torch.no_grad():
        sim_sir = sir.observe(sir.run((flow.sample(1)[0][0])))
    ax.plot(sim_sir[0].numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[1].numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_data[0], color = "black", linewidth=2, label = "data infected")
ax.plot(true_data[1], color = "black", linewidth=2, label = "data recovered", linestyle="--")

ax.legend()
