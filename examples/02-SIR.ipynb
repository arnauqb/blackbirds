# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # SIR model

# %% [markdown]
# Here we calibrate a differentiable version of the SIR model.
# We use the exact same model as  https://ndlib.readthedocs.io/en/latest/reference/models/epidemics/SIR.html,
# but implemented in a differentiable way.

# %%
from birds.models.sir import SIR
from birds.calibrator import Calibrator

import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx
import normflows as nf
from corner import corner # to plot corner plots
import pygtc

# %% [markdown]
# ## Generating synthetic true data

# %%
# generate a random graph
n_agents = 1000
graph = networkx.watts_strogatz_graph(n_agents, 10, 0.1)

# %%
sir = SIR(graph, n_timesteps=100)

# %%
# %%time
# the simulator takes as parameters the log10 of the fraction of initial cases, beta, and gamma parameters
true_parameters = torch.log10(torch.tensor([0.05, 0.05, 0.05]))
true_data = sir.observe(sir.run(true_parameters))
true_infected, true_recovered = true_data
# Out:
# CPU times: user 49.7 ms, sys: 33.5 ms, total: 83.2 ms
# Wall time: 57.6 ms

# %%
f, ax = plt.subplots()
ax.plot(true_infected, label = "active infected")
ax.set_xlabel("Time-step")
ax.plot(true_recovered, label = "cumulative recovered")
ax.legend()

# %% [markdown]
# ## Approximating the posterior by a normalizing flow

# %% [markdown]
# We construct the flow using the normflows library (https://github.com/VincentStimper/normalizing-flows )

# %% [markdown]
# In this case we define Neural Spline Flow with 4 transformations, each parametrised by 2 layers with 64 hidden units.

# %%
def setup_flow():
    K = 4
    torch.manual_seed(0)
    
    latent_size = 3
    hidden_units = 64
    hidden_layers = 2
    
    flows = []
    for i in range(K):
        flows += [nf.flows.AutoregressiveRationalQuadraticSpline(latent_size, hidden_layers, hidden_units)]
        flows += [nf.flows.LULinearPermute(latent_size)]
    
    # Set prior and q0
    q0 = nf.distributions.DiagGaussian(3, trainable=False)
        
    # Construct flow model
    flow = nf.NormalizingFlow(q0=q0, flows=flows)
    return flow

# %%
# Plot the inital flow:
flow = setup_flow()
samples = flow.sample(10000)[0].detach().numpy()

corner(samples, truths=true_parameters.numpy());

# %% [markdown]
# Let's also plot runs sampled from the untrained flow, to compare later with the trained flow.

# %%
# compare the predictions to the synthetic data:

f, ax = plt.subplots()

for i in range(15):
    with torch.no_grad():
        sim_sir = sir.observe(sir.run(flow.sample(1)[0][0]))
    ax.plot(sim_sir[0].numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[1].numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_data[0], color = "black", linewidth=2, label = "data infected")
ax.plot(true_data[1], color = "black", linewidth=2, label = "data recovered", linestyle="--")

ax.legend()

# %% [markdown]
# ### Train the flow

# %%
torch.manual_seed(0)

# Define a prior
prior = torch.distributions.MultivariateNormal(-2.0 * torch.ones(3), torch.eye(3))

optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-3)

# We set the regularisation weight to 10.
w = 0

calibrator = Calibrator(model = sir,
                        posterior_estimator = flow,
                        prior=prior,
                        data=true_data,
                        optimizer=optimizer,
                        w=w,
                        n_samples_per_epoch=5,
                        log_tensorboard=True,
                       )

# and we run for 500 epochs without early stopping.

calibrator.run(n_epochs=1000, max_epochs_without_improvement=np.inf);
# Out:
#  62%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                        | 623/1000 [51:23<31:05,  4.95s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 23
#      11 calibrator = Calibrator(model = sir,
#      12                         posterior_estimator = flow,
#      13                         prior=prior,
#    (...)
#      18                         log_tensorboard=True,
#      19                        )
#      21 # and we run for 500 epochs without early stopping.
# ---> 23 calibrator.run(n_epochs=1000, max_epochs_without_improvement=np.inf);
#
# File ~/code/birds/birds/calibrator.py:146, in Calibrator.run(self, n_epochs, max_epochs_without_improvement)
#     144 self.losses_hist = defaultdict(list)
#     145 for epoch in iterator:
# --> 146     loss, forecast_loss, regularisation_loss = self.step()
#     147     if mpi_rank == 0:
#     148         self.losses_hist["total"].append(loss.item())
#
# File ~/code/birds/birds/calibrator.py:98, in Calibrator.step(self)
#      96     self.optimizer.zero_grad()
#      97 # compute and differentiate forecast loss
# ---> 98 forecast_loss = compute_and_differentiate_forecast_loss(
#      99     loss_fn=self.forecast_loss,
#     100     model=self.model,
#     101     posterior_estimator=self.posterior_estimator,
#     102     n_samples=self.n_samples_per_epoch,
#     103     observed_outputs=self.data,
#     104     diff_mode=self.diff_mode,
#     105     gradient_estimation_method=self.gradient_estimation_method,
#     106     jacobian_chunk_size=self.jacobian_chunk_size,
#     107     gradient_horizon=self.gradient_horizon,
#     108     device=self.device,
#     109 )
#     110 # compute and differentiate regularisation loss
#     111 if mpi_rank == 0:
#
# File ~/code/birds/birds/forecast.py:344, in compute_and_differentiate_forecast_loss(loss_fn, model, posterior_estimator, n_samples, observed_outputs, diff_mode, gradient_estimation_method, jacobian_chunk_size, gradient_horizon, device)
#     324 r"""Computes and differentiates the forecast loss according to the chosen gradient estimation method
#     325 and automatic differentiation mechanism.
#     326 **Arguments:**
#    (...)
#     337 - `device`: device to use for the computation
#     338 """
#     339 if gradient_estimation_method == "pathwise":
#     340     (
#     341         forecast_parameters,
#     342         forecast_loss,
#     343         forecast_jacobians,
# --> 344     ) = compute_forecast_loss_and_jacobian_pathwise(
#     345         loss_fn=loss_fn,
#     346         model=model,
#     347         posterior_estimator=posterior_estimator,
#     348         observed_outputs=observed_outputs,
#     349         n_samples=n_samples,
#     350         diff_mode=diff_mode,
#     351         device=device,
#     352         jacobian_chunk_size=jacobian_chunk_size,
#     353         gradient_horizon=gradient_horizon,
#     354     )
#     355     if mpi_rank == 0:
#     356         _differentiate_forecast_loss_pathwise(
#     357             forecast_parameters, forecast_jacobians
#     358         )
#
# File ~/code/birds/birds/forecast.py:204, in compute_forecast_loss_and_jacobian_pathwise(loss_fn, model, posterior_estimator, n_samples, observed_outputs, diff_mode, jacobian_chunk_size, gradient_horizon, device)
#     202 for i in range(mpi_rank, len(params_list_comm), mpi_size):
#     203     params = torch.tensor(params_list_comm[i], device=device)
# --> 204     jacobian, loss_i = jacobian_calculator(params)
#     205     if torch.isnan(loss_i) or torch.isnan(jacobian).any():
#     206         continue
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:598, in jacrev.<locals>.wrapper_fn(*args)
#     596     flat_jacobians_per_input = compute_jacobian_preallocate_and_copy()
#     597 else:
# --> 598     flat_jacobians_per_input = compute_jacobian_stacked()
#     600 # Step 2: The returned jacobian is one big tensor per input. In this step,
#     601 # we split each Tensor by output.
#     602 flat_jacobians_per_input = [result.split(flat_output_numels, dim=0) for result in flat_jacobians_per_input]
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:529, in jacrev.<locals>.wrapper_fn.<locals>.compute_jacobian_stacked()
#     527     chunked_result = vjp_fn(basis)
#     528 else:  # chunk_size is None or chunk_size != 1
# --> 529     chunked_result = vmap(vjp_fn)(basis)
#     531 flat_results, _ = tree_flatten(chunked_result)
#     533 if chunk_size == 1:
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/vmap.py:434, in vmap.<locals>.wrapped(*args, **kwargs)
#     430     return _chunked_vmap(func, flat_in_dims, chunks_flat_args,
#     431                          args_spec, out_dims, randomness, **kwargs)
#     433 # If chunk_size is not specified.
# --> 434 return _flat_vmap(
#     435     func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs
#     436 )
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/vmap.py:39, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      36 @functools.wraps(f)
#      37 def fn(*args, **kwargs):
#      38     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 39         return f(*args, **kwargs)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/vmap.py:619, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     617 try:
#     618     batched_inputs = _create_batched_inputs(flat_in_dims, flat_args, vmap_level, args_spec)
# --> 619     batched_outputs = func(*batched_inputs, **kwargs)
#     620     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#     621 finally:
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:325, in _vjp_with_argnums.<locals>.wrapper(cotangents, retain_graph, create_graph)
#     319 if primals_out_spec != cotangents_spec:
#     320     raise RuntimeError(
#     321         f'Expected pytree structure of cotangents to be the same '
#     322         f'as pytree structure of outputs to the function. '
#     323         f'cotangents: {treespec_pprint(cotangents_spec)}, '
#     324         f'primal output: {treespec_pprint(primals_out_spec)}')
# --> 325 result = _autograd_grad(flat_primals_out, flat_diff_primals, flat_cotangents,
#     326                         retain_graph=retain_graph, create_graph=create_graph)
#     327 return tree_unflatten(result, primals_spec)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:113, in _autograd_grad(outputs, inputs, grad_outputs, retain_graph, create_graph)
#     111 if len(diff_outputs) == 0:
#     112     return tuple(torch.zeros_like(inp) for inp in inputs)
# --> 113 grad_inputs = torch.autograd.grad(diff_outputs, inputs, grad_outputs,
#     114                                   retain_graph=retain_graph,
#     115                                   create_graph=create_graph,
#     116                                   allow_unused=True)
#     117 grad_inputs = tuple(torch.zeros_like(inp) if gi is None else gi
#     118                     for gi, inp in zip(grad_inputs, inputs))
#     119 return grad_inputs
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/autograd/__init__.py:307, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     305     return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     306 else:
# --> 307     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     308         t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     309         allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:

# %%
# Let's have a look at the loss over epochs:

df = pd.DataFrame(calibrator.losses_hist)
df.plot(logy=True)
# Out:
# <Axes: >

# %%
# We can load the best model to check the results
flow.load_state_dict(calibrator.best_model_state_dict)
# Out:
# <All keys matched successfully>

# %%
# Plot the final flow posterior approximator and compare it to the real parameters:
samples = flow.sample(50000)[0].detach().numpy()

#corner(samples, truths=true_parameters.numpy(), smooth=2, range = ((-2, -1.0), (-1.7, -1.0), (-1.4, -1.25)), labels=["initial_fraction_infected", r"$\beta$", r"$\gamma$"]);
#corner(samples, truths=true_parameters.numpy(), smooth=2, labels=["initial_fraction_infected", r"$\beta$", r"$\gamma$"]);
pygtc.plotGTC([samples], truths=true_parameters.numpy(), figureSize=10, priors=[(-2, 1) for i in range(3)]);

# %%
# compare the predictions to the synthetic data:

f, ax = plt.subplots()

for i in range(25):
    with torch.no_grad():
        sim_sir = sir.observe(sir.run((flow.sample(1)[0][0])))
    ax.plot(sim_sir[0].numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[1].numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_data[0], color = "black", linewidth=2, label = "data infected")
ax.plot(true_data[1], color = "black", linewidth=2, label = "data recovered", linestyle="--")

ax.legend()
