# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # SIR model

# %% [markdown]
# Here we calibrate a differentiable version of the SIR model.
# We use the exact same model as  https://ndlib.readthedocs.io/en/latest/reference/models/epidemics/SIR.html,
# but implemented in a differentiable way.

# %%
from birds.models.sir import SIR
from birds.calibrator import Calibrator

import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx
import normflows as nf
from corner import corner # to plot corner plots

# %% [markdown]
# ## Generating synthetic true data

# %%
# generate a random graph
n_agents = 1000
graph = networkx.watts_strogatz_graph(n_agents, 10, 0.1)

# %%
sir = SIR(graph, n_timesteps=100)

# %%
# %%time
# the simulator takes as parameters the log10 of the fraction of initial cases, beta, and gamma parameters
true_parameters = torch.log10(torch.tensor([0.05, 0.05, 0.05]))
true_data = sir.observe(sir.run(true_parameters))
true_infected, true_recovered = true_data
# Out:
# CPU times: user 55.1 ms, sys: 33 ms, total: 88.2 ms
# Wall time: 62.3 ms

# %%
f, ax = plt.subplots()
ax.plot(true_infected, label = "active infected")
ax.set_xlabel("Time-step")
ax.plot(true_recovered, label = "cumulative recovered")
ax.legend()

# %% [markdown]
# ## Approximating the posterior by a normalizing flow

# %% [markdown]
# We construct the flow using the normflows library (https://github.com/VincentStimper/normalizing-flows )

# %% [markdown]
# In this case we define Neural Spline Flow with 4 transformations, each parametrised by 2 layers with 64 hidden units.

# %%
# Define flows
K = 4
torch.manual_seed(0)

latent_size = 3
hidden_units = 64
hidden_layers = 2

flows = []
for i in range(K):
    flows += [nf.flows.AutoregressiveRationalQuadraticSpline(latent_size, hidden_layers, hidden_units)]
    flows += [nf.flows.LULinearPermute(latent_size)]

# Set prior and q0
q0 = nf.distributions.DiagGaussian(3, trainable=False)
    
# Construct flow model
flow = nf.NormalizingFlow(q0=q0, flows=flows)

# %%
# Plot the inital flow:
samples = flow.sample(10000)[0].detach().numpy()

corner(samples, truths=true_parameters.numpy());

# %% [markdown]
# Let's also plot runs sampled from the untrained flow, to compare later with the trained flow.

# %%
# compare the predictions to the synthetic data:

f, ax = plt.subplots()

for i in range(15):
    with torch.no_grad():
        sim_sir = sir.observe(sir.run(flow.sample(1)[0][0]))
    ax.plot(sim_sir[0].numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[1].numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_data[0], color = "black", linewidth=2, label = "data infected")
ax.plot(true_data[1], color = "black", linewidth=2, label = "data recovered", linestyle="--")

ax.legend()

# %% [markdown]
# ### Train the flow

# %%
torch.manual_seed(0)

# Define a prior
prior = torch.distributions.MultivariateNormal(-2.0 * torch.ones(3), torch.eye(3))

optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-3)

# We set the regularisation weight to 10.
w = 10

# Note that we can track the progress of the training by using tensorboard.
# tensorboard --logdir=runs
log_dir = "./runs/sir_run"

calibrator = Calibrator(model = sir, posterior_estimator = flow, prior=prior, data=true_data, optimizer=optimizer, w=w, tensorboard_log_dir=log_dir)

# and we run for 500 epochs without early stopping.

calibrator.run(n_epochs=500, max_epochs_without_improvement=np.inf);
# Out:
#   0%|                                                                                                                                                                                                                                                                                               | 0/500 [00:00<?, ?it/s]
# torch.Size([3, 1000])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 19
#      15 calibrator = Calibrator(model = sir, posterior_estimator = flow, prior=prior, data=true_data, optimizer=optimizer, w=w, tensorboard_log_dir=log_dir)
#      17 # and we run for 500 epochs without early stopping.
# ---> 19 calibrator.run(n_epochs=500, max_epochs_without_improvement=np.inf);
#
# File ~/code/birds/birds/calibrator.py:143, in Calibrator.run(self, n_epochs, max_epochs_without_improvement)
#     141 self.losses_hist = defaultdict(list)
#     142 for epoch in iterator:
# --> 143     loss, forecast_loss, regularisation_loss = self.step()
#     144     if mpi_rank == 0:
#     145         self.losses_hist["total"].append(loss.item())
#
# File ~/code/birds/birds/calibrator.py:95, in Calibrator.step(self)
#      93     self.optimizer.zero_grad()
#      94 # compute and differentiate forecast loss
# ---> 95 forecast_loss = compute_and_differentiate_forecast_loss(
#      96     loss_fn=self.forecast_loss,
#      97     model=self.model,
#      98     posterior_estimator=self.posterior_estimator,
#      99     n_samples=self.n_samples_per_epoch,
#     100     observed_outputs=self.data,
#     101     diff_mode=self.diff_mode,
#     102     gradient_estimation_method=self.gradient_estimation_method,
#     103     jacobian_chunk_size=self.jacobian_chunk_size,
#     104     gradient_horizon=self.gradient_horizon,
#     105     device = self.device
#     106 )
#     107 # compute and differentiate regularisation loss
#     108 if mpi_rank == 0:
#
# File ~/code/birds/birds/forecast.py:360, in compute_and_differentiate_forecast_loss(loss_fn, model, posterior_estimator, n_samples, observed_outputs, diff_mode, gradient_estimation_method, jacobian_chunk_size, gradient_horizon, device)
#     340 r"""Computes and differentiates the forecast loss according to the chosen gradient estimation method
#     341 and automatic differentiation mechanism.
#     342 **Arguments:**
#    (...)
#     353 - `device`: device to use for the computation
#     354 """
#     355 if gradient_estimation_method == "pathwise":
#     356     (
#     357         forecast_parameters,
#     358         forecast_loss,
#     359         forecast_jacobians,
# --> 360     ) = compute_forecast_loss_and_jacobian_pathwise(
#     361         loss_fn=loss_fn,
#     362         model=model,
#     363         posterior_estimator=posterior_estimator,
#     364         observed_outputs=observed_outputs,
#     365         n_samples=n_samples,
#     366         diff_mode=diff_mode,
#     367         device=device,
#     368         jacobian_chunk_size=jacobian_chunk_size,
#     369         gradient_horizon=gradient_horizon,
#     370     )
#     371     if mpi_rank == 0:
#     372         _differentiate_forecast_loss_pathwise(
#     373             forecast_parameters, forecast_jacobians
#     374         )
#
# File ~/code/birds/birds/forecast.py:220, in compute_forecast_loss_and_jacobian_pathwise(loss_fn, model, posterior_estimator, n_samples, observed_outputs, diff_mode, jacobian_chunk_size, gradient_horizon, device)
#     218 for i in range(mpi_rank, len(params_list_comm), mpi_size):
#     219     params = torch.tensor(params_list_comm[i], device=device)
# --> 220     jacobian, loss_i = jacobian_calculator(params)
#     221     if torch.isnan(loss_i) or torch.isnan(jacobian).any():
#     222         continue
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:489, in jacrev.<locals>.wrapper_fn(*args)
#     486 @wraps(func)
#     487 def wrapper_fn(*args):
#     488     error_if_complex("jacrev", args, is_input=True)
# --> 489     vjp_out = _vjp_with_argnums(func, *args, argnums=argnums, has_aux=has_aux)
#     490     if has_aux:
#     491         output, vjp_fn, aux = vjp_out
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/vmap.py:39, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      36 @functools.wraps(f)
#      37 def fn(*args, **kwargs):
#      38     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 39         return f(*args, **kwargs)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:291, in _vjp_with_argnums(func, argnums, has_aux, *primals)
#     289     diff_primals = _slice_argnums(primals, argnums, as_tuple=False)
#     290     tree_map_(partial(_create_differentiable, level=level), diff_primals)
# --> 291 primals_out = func(*primals)
#     293 if has_aux:
#     294     if not (isinstance(primals_out, tuple) and len(primals_out) == 2):
#
# File ~/code/birds/birds/forecast.py:202, in compute_forecast_loss_and_jacobian_pathwise.<locals>.loss_f(params)
#     201 def loss_f(params):
# --> 202     simulated_outputs = simulate_and_observe_model(
#     203         model, params, gradient_horizon
#     204     )
#     205     loss = compute_loss(loss_fn, observed_outputs, simulated_outputs)
#     206     return loss
#
# File ~/code/birds/birds/forecast.py:35, in simulate_and_observe_model(model, params, gradient_horizon)
#      33 x = time_series[i]
#      34 if observations is None:
# ---> 35     observations = model.observe(x)
#      36 else:
#      37     observation = model.observe(x)
#
# File ~/code/birds/birds/models/sir.py:102, in SIR.observe(self, x)
#      94 """
#      95 Returns the total number of infected and recovered agents per time-step
#      96
#    (...)
#      99 - x: a tensor of shape (3, n_agents) containing the infected, susceptible, and recovered counts.
#     100 """
#     101 print(x.shape)
# --> 102 return [x[:,0,:].sum(1), x[:,2,:].sum(1)]
#
# IndexError: too many indices for tensor of dimension 2

# %%
# Let's have a look at the loss over epochs:

df = pd.DataFrame(calibrator.losses_hist)
df.plot(logy=True)
# Out:
# <Axes: >

# %%
# We can load the best model to check the results
flow.load_state_dict(calibrator.best_model_state_dict)
# Out:
# <All keys matched successfully>

# %%
# Plot the final flow posterior approximator and compare it to the real parameters:
samples = flow.sample(10000)[0].detach().numpy()

corner(samples, truths=true_parameters.numpy(), smooth=2, range = ((-2, -1.0), (-1.7, -1.0), (-1.4, -1.25)), labels=["initial_fraction_infected", r"$\beta$", r"$\gamma$"]);

# %%
# compare the predictions to the synthetic data:

f, ax = plt.subplots()

for i in range(25):
    with torch.no_grad():
        sim_sir = sir(flow.sample(1)[0][0])
    ax.plot(sim_sir[0].numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[1].numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_data[0], color = "black", linewidth=2, label = "data infected")
ax.plot(true_data[1], color = "black", linewidth=2, label = "data recovered", linestyle="--")

ax.legend()
